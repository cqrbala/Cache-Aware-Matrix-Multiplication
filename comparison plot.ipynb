# %%
import matplotlib.pyplot as plt

# %%
x = [16,32,64,128,256,512,1024,2048,4096]
y1 = [14208,169709,1665000,6997000,38342458,287440916,2272035875,24221793667,206576047292]
y2 = [13667,167458,1528167,6089083,37305625,293018917,2570162084,48415577291,1105041955417]

# %%
plt.title('Plot of Blocked Multiplication and Naive Multiplication')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.plot(x, y1, label='blocked multiplication')
plt.plot(x, y2, label='naive multiplication')

# %%
plt.show()
